# %% [markdown]
# # Pandas built-in Data Visualization
# In this lesson we will learn more about the available VIsualization capabilities of *Pandas*.
# It is based on *Matplotlib*, but is available directly in Pandas for easier handling.
#
# Let's start!
#
# ### Imports

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ### The data
# We have some CSV files with data that we can use as data frames:

# %%
df1 = pd.read_csv("df1",index_col=0)
df2 = pd.read_csv("df2")

# %% [markdown]
# ## stylesheets
# Matplotlib provides [*Stylesheets*](http://matplotlib.org/gallery.html#style_sheets) that we can use to make our charts look a little better. We will look at some of them as examples.
#
# We recommend using the stylesheets as they give all diagrams a consistent look. It is also possible to create your own stylesheets to represent a company, for example.
#
# Now let's look at the usage:
#
# *Before using plt.style.use():*.

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Now we use the stylesheet.

# %%
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
df1['A'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('bmh')
df1['A'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('dark_background')
df1['A'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('fivethirtyeight')
df1['A'].hist()
# Out:
# <Axes: >

# %%
plt.style.use('ggplot')

# %% [markdown]
# Let's leave it at the *ggplot* stylesheet for now and look at the actual visualization capabilities of *Pandas*.
#
# ## Diagram types
# There are several built-in visualizations in *Pandas*. Most of them are statistical charts. Here is an overview:
#
# * df.plot.area
# * df.plot.barh
# * df.plot.density
# * df.plot.hist
# * df.plot.line
# * df.plot.scatter
# * df.plot.bar
# * df.plot.box
# * df.plot.hexbin
# * df.plot.kde
# * df.plot.pie
#
# We can alternatively call df.plot(kind="area").
#
# Now let's take a look at all the plots:

# %% [markdown]
# ### Area

# %%
df2.plot.area(alpha=0.4)
# Out:
# <Axes: >

# %% [markdown]
# ### Barplots

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.bar()
# Out:
# <Axes: >

# %%
df2.plot.bar(stacked=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Histogramm

# %%
df1['A'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# ### Line Plot

# %%
df1.plot.line(y='B',lw=1, figsize=(12,3))
# Out:
# <Axes: >

# %% [markdown]
# ### Scatter Plots

# %%
df1.plot.scatter(x='A',y='B')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# We can use except *c* to color the points using a third variable. To do this, we define `cmap` with one of the [Colormaps](http://matplotlib.org/users/colormaps.html).

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')
# Out:
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# Or we use `s` to change the size (en. scale) of the points. The `s` parameter must be an array. We see here how it works:

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100)
# Out:
# c:\code\programmieruebung2\.venv\Lib\site-packages\matplotlib\collections.py:996: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <Axes: xlabel='A', ylabel='B'>

# %% [markdown]
# ### Box Plots

# %%
df2.plot.box() # We can also group by with by= (en. group by)
# Out:
# <Axes: >

# %% [markdown]
# ### Hexagonal Bin Plot
# A useful alternative to the scatterplot for bivariate data:

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges')
# Out:
# <Axes: xlabel='a', ylabel='b'>

# %% [markdown]
# ### Kernel Density Estimation (KDE) Plot

# %%
df2['a'].plot.kde()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df2['a'].plot.kde()
#
# File c:\code\programmieruebung2\.venv\Lib\site-packages\pandas\plotting\_core.py:1522, in PlotAccessor.kde(self, bw_method, ind, **kwargs)
#    1411 def kde(
#    1412     self,
#    1413     bw_method: Literal["scott", "silverman"] | float | Callable | None = None,
#    1414     ind: np.ndarray | int | None = None,
#    1415     **kwargs,
#    1416 ) -> PlotAccessor:
#    1417     """
#    1418     Generate Kernel Density Estimate plot using Gaussian kernels.
#    1419
#    (...)
#    1520         >>> ax = df.plot.kde(ind=[1, 2, 3, 4, 5, 6])
#    1521     """
# -> 1522     return self(kind="kde", bw_method=bw_method, ind=ind, **kwargs)
#
# File c:\code\programmieruebung2\.venv\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
# ...

# %%
df2.plot.density()
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# And with that we have them all. Hopefully, you will find this variant of visualization easier than complete Matplotlib approach. It provides a good balance of simplicity and control. Also, for many of the diagrams, we can pass more parameters (just like their matplotlib parent diagrams).

# %% [markdown]
# # 🏁 Recap Pandas visualization
#
# - If you have finished the tasks and have no questions, start with `Task_3_Pandas_Visualization`.
# - If you have finished the tasks but would like to discuss the solutions together again, please tell your teacher!
#
# <table style="width: 100%">
#     <tr style="background: #ff9900">
#         <td style="width: 100%">
#             <div style="text-align:center; width: 100%; text-align:center"><font style="font-size:38px"><b>Good Job!</b></font></div>
#             <div style="padding-top:0px; width: 100%; text-align:right"><font size="4"><b>SoSe 2023</b></font></div>
#         </td>
#     </tr>
# </table>
