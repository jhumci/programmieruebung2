# %% [markdown]
# # Task
#
# You are given a list containing 502 list of EKG-Time Series (Voltages in mV). The time series overlap. Your task is to ressable the time series into one list again.

# %%
# %%
 
import csv
file = open("corrupted_files.txt", "r")
data = list(csv.reader(file, delimiter="\t"))
file.close()

# %%
len(data)
# Out:
# 502

# %%
data[0]
# Out:
# ["['309', '307', '306', '304', '303', '301', '299', '298', '297', '296', '295', '294', '293', '292', '291', '291', '290', '289', '288', '288', '287', '287', '287', '286', '286', '286', '285', '285', '285', '285', '285', '285', '285', '285', '285', '285', '285', '285', '285', '285', '286', '286', '286', '287', '287', '287', '287', '288', '288', '288', '289', '289', '290', '290', '291', '292', '292', '293', '294', '294', '295', '296', '297', '297', '298', '299', '300', '301', '302', '303', '304', '306', '307', '308', '309', '310', '311', '313', '313', '314', '315', '317', '318', '319', '320', '321', '321', '322', '323', '324', '325', '325', '326', '326', '327', '327', '328', '327', '327', '327', '327', '327', '326', '326', '325', '325', '324', '323', '322', '321', '320', '318', '317', '316', '315', '313', '312', '311', '309', '308', '306', '305', '304', '302', '301', '300', '298', '297', '296', '295', '294', '293', '292', '291', '290', '290', '289', '288', '287', '287', '286', '286', '286', '285', '285', '285', '284', '284', '283', '283', '283', '283', '283', '282', '283', '282', '283', '282', '282', '282', '282', '282', '282', '282', '282', '282', '282', '282', '283', '283', '283', '283', '283', '283', '283', '283', '283', '283', '283', '283', '283', '284', '284', '284', '284', '284', '284', '284', '284', '284', '285', '285', '285', '285', '285', '285', '285', '285', '286', '286', '286', '286', '286', '286', '286', '287', '287', '287', '287', '287', '287', '287', '288', '288', '288', '288', '288', '288', '288', '288', '289', '289', '289', '289', '289', '290', '290', '290', '291', '291', '292', '292', '293', '293', '293', '294', '294', '295', '295', '295', '295', '296', '296', '297', '297', '298', '299', '299', '299', '300', '300', '301', '301', '301', '301', '301', '302', '302', '302', '302', '302', '302', '302', '302', '302', '302', '301', '301', '301', '301', '301', '300', '300', '300', '300', '299', '299', '298', '298', '298', '298', '297', '297', '297', '297', '297', '297', '296', '296', '296', '296', '296', '296', '296', '296', '295', '295', '294', '294', '294', '293', '293', '293', '295', '297', '299', '303', '308', '315', '321', '329', '337', '346', '354', '361', '367', '371', '375', '377', '378', '377', '377', '376', '374', '372', '369', '366', '363', '359', '356', '354', '350', '347', '344', '341', '338', '335', '331', '329', '326', '323', '321', '318', '316', '313', '312', '309', '308', '306', '304', '302', '301', '299', '297', '296', '295', '294', '292', '292', '291', '289', '289', '288', '287', '287', '286', '285', '285', '284', '284', '284', '284', '283', '283', '283', '283', '283', '283', '283', '283', '283', '283', '283', '283', '283', '283', '283', '284', '284', '285', '285', '285', '285', '286', '286', '286', '287', '288', '288', '289', '289', '290', '291', '291', '292', '293', '293', '294', '295', '296', '297', '298', '299', '300', '301', '302', '304', '305', '306', '307', '308', '310', '311', '312', '313', '314', '316', '317', '318', '319', '320', '321', '322', '322', '323', '324', '324', '325', '325', '326', '326', '326', '327', '326', '326', '326', '326', '325', '325', '324', '323', '323', '322', '321', '319', '318', '318', '316', '315', '314', '313', '311', '310', '308', '307', '306', '304', '303', '302', '300', '299', '298', '296', '296', '294', '293', '292', '291', '291', '290', '289', '288', '288', '287', '286', '286', '285', '285', '284', '284', '284', '283', '283', '283', '283', '283', '282', '282', '282', '282', '282', '281', '281', '282', '282', '282', '281', '281', '281', '282', '282', '282', '282', '282', '282', '282', '282', '282', '282', '282', '282', '283', '282', '283', '283', '283', '283', '283', '283', '283', '283', '284', '284', '284', '284', '284', '284', '284', '284', '285', '285', '285', '285', '285', '285', '286', '286', '286', '286', '286', '286', '286', '286', '287', '287', '287', '287', '287', '288', '288', '288', '288', '288', '288', '289', '289', '289', '289', '290', '290', '291',  ...

# %% [markdown]
# Starting points
# The challenge is devided into various subproblems. Each subproblem can be solved with a function. If you implement all function, You can pass the assignmenteven if You would fail to complete the sequence assembly.
#
# The outline of the functions is given below. You can also find a unit test for each function below.
#
# First, implement end test the following four functions. Run the unit test below, to make sure they work.

# %%
Starting points
The challenge is devided into various subproblems. Each subproblem can be solved with a function. If you implement all function, You can pass the assignmenteven if You would fail to complete the sequence assembly.

The outline of the functions is given below. You can also find a unit test for each function below.

First, implement end test the following four functions. Run the unit test below, to make sure they work.

# %%
list_of_fragments
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-912252ac022f> in <module>
# ----> 1 list_of_fragments
#
# NameError: name 'list_of_fragments' is not defined

# %%
list_of_fragments
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-912252ac022f> in <module>
# ----> 1 list_of_fragments
#
# NameError: name 'list_of_fragments' is not defined

# %%
ekg_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-bfb2ca84d597> in <module>
# ----> 1 ekg_data
#
# NameError: name 'ekg_data' is not defined
